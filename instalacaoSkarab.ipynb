# %% [markdown]
# ## INSTALAÇÃO SKARAB
#
# LISTA DE SOFTWARES NECESSARIOS:
#
# - [Ubuntu 16.04](https://releases.ubuntu.com/16.04/)
# - [Matlab 2018a]()
# - Vivado 2019.1.1
# - Python 3
# - mlib_devel branch: master
